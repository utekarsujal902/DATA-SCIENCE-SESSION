# %%
price=1000
discount=0.2
tax=0.12
final_price=price-(price*discount)
final_price=final_price+(final_price*tax)
print("Final Price after discount:",final_price
    )
# Out:
# Final Price after discount: 896.0

# %%
customer_name="Rahul"
age=25
salary=55000.75
is_fraud=False
print(type(customer_name))
print(type(age))
print(type(salary))
print(type(is_fraud))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
age=30
salary=55000.0
loan_amount=200000
existing_loans=2
credit_score=720
is_citizen=True

emi=loan_amount/12
total_income_yearly=salary*12
remaining_salary=total_income_yearly-(emi*12)
print("Monthly EMI:",emi)
print("Remaining Salary:",remaining_salary)
print("Is credit score good?",credit_score>700)
print("Is EMI is less than 50% of salary?",emi<(salary*0.5))
print("Is age less than 60?",age<60)
eligible=(credit_score>700) and (emi<(salary*0.5)) and (age<60) and is_citizen
print("Loan Eligibility:",eligible)
# Out:
# Monthly EMI: 16666.666666666668
# Remaining Salary: 460000.0
# Is credit score good? True
# Is EMI is less than 50% of salary? True
# Is age less than 60? True
# Loan Eligibility: True

# %%
cds43

# %%
item1=1200
item2=800
item3=600
discount=0.1
total=item1+item2+item3
final_bill=total-(total*discount)
print("Total Bill:",total)
print("Final Bill:",final_bill)
Gst=0.18
final_bill=final_bill+(final_bill*Gst)
print("Final Bill after GST:",final_bill)
# Out:
# Total Bill: 2600
# Final Bill: 2340.0
# Final Bill after GST: 2761.2

# %%
marks=int(input("Enter your score:"))
if marks>=95:
    print("Grade: A+(Outstanding!)")
elif marks>=90:
    print("Grade: A(Excellent)")
elif marks>=70:
    print("Grade: B(Good)")
elif marks>=50:
    print("Grade: C(Needs Improvement)")
else:
    print("Grade: D(Fail)")
# Out:
# Enter your score:77
# Grade: B(Good)

# %%
from os import name
customers =["Rahul","Priya","Amit","Smaha","Vikram"]
for customer in customers:
    print("Sending email to:",customer)
# Out:
# Sending email to: Rahul
# Sending email to: Priya
# Sending email to: Amit
# Sending email to: Smaha
# Sending email to: Vikram

# %%
for i in range(1,6):
    print("Reminder email number:",i)
# Out:
# Reminder email number: 1
# Reminder email number: 2
# Reminder email number: 3
# Reminder email number: 4
# Reminder email number: 5

# %%
students={"Rahul":85,"Priya":92,"Amit":74,"Sujal":95,"Vikram":68}
for name,marks in students.items():
    if marks>=90:
        grade="A"
    elif marks>=75:
      grade="B"
    elif marks>=60:
        grade="C"
    else:
        grade="D"
    print(f"Student:{name},Marks:{marks},Grade:{grade}")
# Out:
# Student:Rahul,Marks:85,Grade:B
# Student:Priya,Marks:92,Grade:A
# Student:Amit,Marks:74,Grade:C
# Student:Sujal,Marks:95,Grade:A
# Student:Vikram,Marks:68,Grade:C

# %%
def greet(name):
    print("Hello", name, "welcome to the Bootcamp!")
greet("Rahul")
greet("Priya")
# Out:
# Hello Rahul welcome to the Bootcamp!
# Hello Priya welcome to the Bootcamp!

# %%
def calculate_discount(price, discount_percent):
 return price - (price * discount_percent / 100)
def apply_tax(price, tax_percent):
 return price + (price * tax_percent / 100)
# Example product
price = 1000
discounted_price = calculate_discount(price, 10) # 10% discount
final_price = apply_tax(discounted_price, 18) # 18% GST
print("Final Price after discount and tax:", final_price)
# Out:
# Final Price after discount and tax: 1062.0

# %%
import math
print("Square root of 25:", math.sqrt(25))
print("Value of pi:", math.pi)
# Out:
# Square root of 25: 5.0
# Value of pi: 3.141592653589793

# %%
# Function to issue books
def issue_books(student_name, books):
    print(f"\n {student_name} borrowed:")
    for book in books:
        print("-", book)
# Function to calculate fine
def calculate_fine(days_late):
    fine_per_day = 5
    return days_late * fine_per_day
# Function to generate report
def student_report(student_name, books, days_late):
    issue_books(student_name, books)
    fine = calculate_fine(days_late)
    print(f"Fine to be paid: ₹{fine}\n")
# Example usage
student_report("Rahul", ["Python Basics", "Data Science 101"], 3)
student_report("Priya", ["Machine Learning"], 0)
# Out:
#  Rahul borrowed:
# - Python Basics
# - Data Science 101
# Fine to be paid: ₹15
#
#
#  Priya borrowed:
# - Machine Learning
# Fine to be paid: ₹0
